# %%
import sys
print(sys.executable)
# Out:
# e:\AI_ML\Tensorflow\tfenv\Scripts\python.exe

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.20.0

# %%
tf.test.gpu_device_name
# Out:
# <function tensorflow.python.framework.test_util.gpu_device_name() -> str>

# %%
import numpy as np

# %%
import time

# %%
np_array = np.random.uniform(size = [5000,5000])

# %%
np_array
# Out:
# array([[0.72340087, 0.69622306, 0.0205848 , ..., 0.28076991, 0.80157707,
#         0.18884124],
#        [0.59395425, 0.91991485, 0.87865456, ..., 0.88538714, 0.33989712,
#         0.99301668],
#        [0.37767214, 0.37484968, 0.49713819, ..., 0.10969031, 0.46264696,
#         0.46764365],
#        ...,
#        [0.11458234, 0.20470932, 0.43090461, ..., 0.52151808, 0.59327528,
#         0.31988751],
#        [0.35631153, 0.98331098, 0.86115134, ..., 0.70558872, 0.20040891,
#         0.09365628],
#        [0.60761571, 0.53483892, 0.55486541, ..., 0.62765546, 0.35843238,
#         0.90822759]], shape=(5000, 5000))

# %%
start = time.time()
for i in range(10):
  np.matmul(np_array,np_array)
  end = time.time()
  print(end-start)
# Out:
# 1.6233620643615723
# 3.2271454334259033
# 4.997898817062378
# 6.6828224658966064
# 8.342600107192993
# 10.021565675735474
# 11.789791107177734
# 13.595208644866943
# 15.40671443939209
# 17.11715793609619

# %%
tf_array = tf.random.uniform(shape = [5000,5000])

# %%
start = time.time()
for i in range(10):
  tf.matmul(np_array,np_array)
  end = time.time()
  print(end-start)
# Out:
# 5.464515924453735
# 11.923815250396729
# 18.227588415145874
# 24.482651472091675
# 30.964085340499878
# 37.0790901184082
# 43.158950090408325
# 49.282639026641846
# 55.42801833152771
# 61.72364330291748
